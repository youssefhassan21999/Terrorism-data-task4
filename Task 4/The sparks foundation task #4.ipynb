# %% [markdown]
# # Youssef Ahmed Hassan

# %% [markdown]
# > The sparks foundation, task 4.

# %% [raw]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
df = pd.read_csv('globalterrorismdb_0718dist.csv')
df.head()
# Out:
# D:\Programs\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
columns_to_work_with = ['iyear','country_txt','region_txt','provstate','city','attacktype1_txt','targtype1_txt','target1','natlty1_txt','gname','weaptype1_txt','nkill','nwound']
new_df = df[columns_to_work_with].copy()
new_df.head()
# Out:
#    iyear         country_txt                   region_txt provstate  \
# 0   1970  Dominican Republic  Central America & Caribbean       NaN
# 1   1970              Mexico                North America   Federal
# 2   1970         Philippines               Southeast Asia    Tarlac
# 3   1970              Greece               Western Europe    Attica
# 4   1970               Japan                    East Asia   Fukouka
#
#             city                 attacktype1_txt                targtype1_txt  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                    target1         natlty1_txt  \
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   iyear            181691 non-null  int64
#  1   country_txt      181691 non-null  object
#  2   region_txt       181691 non-null  object
#  3   provstate        181270 non-null  object
#  4   city             181257 non-null  object
#  5   attacktype1_txt  181691 non-null  object
#  6   targtype1_txt    181691 non-null  object
#  7   target1          181055 non-null  object
#  8   natlty1_txt      180132 non-null  object
#  9   gname            181691 non-null  object
#  10  weaptype1_txt    181691 non-null  object
#  11  nkill            171378 non-null  float64
#  12  nwound           165380 non-null  float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 18.0+ MB

# %%
new_df.isnull().sum()
# Out:
# iyear                  0
# country_txt            0
# region_txt             0
# provstate            421
# city                 434
# attacktype1_txt        0
# targtype1_txt          0
# target1              636
# natlty1_txt         1559
# gname                  0
# weaptype1_txt          0
# nkill              10313
# nwound             16311
# dtype: int64

# %%
new_df.dropna(inplace = True)

# %%
new_df.isnull().sum()
# Out:
# iyear              0
# country_txt        0
# region_txt         0
# provstate          0
# city               0
# attacktype1_txt    0
# targtype1_txt      0
# target1            0
# natlty1_txt        0
# gname              0
# weaptype1_txt      0
# nkill              0
# nwound             0
# dtype: int64

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 161981 entries, 1 to 181690
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   iyear            161981 non-null  int64
#  1   country_txt      161981 non-null  object
#  2   region_txt       161981 non-null  object
#  3   provstate        161981 non-null  object
#  4   city             161981 non-null  object
#  5   attacktype1_txt  161981 non-null  object
#  6   targtype1_txt    161981 non-null  object
#  7   target1          161981 non-null  object
#  8   natlty1_txt      161981 non-null  object
#  9   gname            161981 non-null  object
#  10  weaptype1_txt    161981 non-null  object
#  11  nkill            161981 non-null  float64
#  12  nwound           161981 non-null  float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 17.3+ MB

# %%
years_count = new_df['iyear'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (20,10))
sns.barplot(x = new_df['iyear'].unique(), y = years_count)
plt.xticks(rotation = 50)
plt.xlabel('Year of attack',fontsize=20)
plt.ylabel('Number of attacks that year',fontsize=20)
plt.show()

# %%
region_count = new_df['region_txt'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (20,10))
sns.barplot(x = new_df['region_txt'].unique(), y = region_count)
plt.xlabel('Region',fontsize=20)
plt.ylabel('Number of attacks in this region',fontsize=20)
plt.show()

# %%
pd.crosstab(new_df['iyear'], new_df['region_txt']).plot(kind='line',stacked=False,figsize=(20,10))
plt.title('Terrorist Activities By Region In Each Year',fontsize=25)
plt.xticks(rotation = 50)
plt.ylabel('Number of Attacks',fontsize=20)
plt.xlabel("Year",fontsize=20)
plt.show()

# %%
plt.subplots(figsize=(20,10))
sns.barplot(new_df['country_txt'].value_counts()[:10].index,new_df['country_txt'].value_counts()[:10].values,)
plt.title('Top Countries Affected By Terrorism')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation = 50)
plt.show()
# Out:
# D:\Programs\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.subplots(figsize=(20,10))
sns.barplot(new_df['city'].value_counts()[:10].index,new_df['city'].value_counts()[:10].values)
plt.title('Top Cities Affected By Terrorism')
plt.xlabel('Cities')
plt.ylabel('Count')
plt.xticks(rotation = 50)
plt.show()
# Out:
# D:\Programs\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.subplots(figsize=(20,10))
sns.barplot(new_df['attacktype1_txt'].value_counts()[:10].index,new_df['attacktype1_txt'].value_counts()[:10].values)
plt.title('Top attack types')
plt.xlabel('attack types')
plt.ylabel('Count')
plt.xticks(rotation = 50)
plt.show()
# Out:
# D:\Programs\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
new_df[['attacktype1_txt','nkill']].groupby(["attacktype1_txt"],axis=0).sum().plot(kind='bar',figsize=(20,10),color=['darkslateblue'])
plt.xticks(rotation=50)
plt.title("Number of killed people/ attack type",fontsize=20)
plt.ylabel('Number of people',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.show()

# %%
new_df['gname'].value_counts().to_frame().drop('Unknown').head(10).plot(kind='bar',color='green',figsize=(20,10))
plt.title('Top gang names')
plt.xlabel('gang names')
plt.ylabel('Count')
plt.xticks(rotation = 50)
plt.show()

# %%
new_df[['gname','nkill']].groupby(['gname'],axis=0).sum().drop('Unknown').sort_values('nkill',ascending=False).head(10).plot(kind='bar',color='yellow',figsize=(20,10))
plt.title("Top 10 terrorist group attack by number of kills",fontsize=20)
plt.xlabel("terrorist group name",fontsize=15)
plt.ylabel("No of killed people",fontsize=15)
plt.show()

# %%
new_df['natlty1_txt'].value_counts().to_frame().head(10).plot(kind='bar',color='green',figsize=(20,10))
plt.title('Top nationalities damged due terrorism')
plt.xlabel('nationality')
plt.ylabel('Count')
plt.xticks(rotation = 50)
plt.show()

# %%
new_df[['natlty1_txt','nkill']].groupby(['natlty1_txt'],axis=0).sum().sort_values('nkill',ascending=False).head(10).plot(kind='bar',color='green',figsize=(20,10))
plt.title("Top 10 countires affected by terrosim / no. of deaths",fontsize=20)
plt.xlabel("country",fontsize=15)
plt.ylabel("No of killed people",fontsize=15)
plt.show()

# %% [markdown]
# # Conclusions

# %% [markdown]
# > From the previous exploratory anlaysis we find that:
# > 1- The year with the most number of attacks was 2014.
# > 2- The region with the most attacks is the middle east and north africa.
# > 3- The country that suffred the most from terroristic attacks was Iraq.
# > 4- The top city that suffred the most from terroristic attacks was baghdad the capital of Iraq.
# > 5- The type of attack that happned the most was Bombing or explosion
# > 6- The group that performed the most attacks was Taliban
# > 7- The group that caused the most number of kills due to attack was ISIL
# > 8- The country that had the most damage and most number of killed people due to terroristic attacks was Iraq.
